# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 데이터프레임 고급 인덱싱
# 판다스 데이터프레임의 인덱싱은 라벨, 라벨 리스트, 행 인덱스 슬라이스의 인덱싱 형태 뿐만 아니라 numpy와 같은 `,`를 이용한
# `(행 인덱스, 열 인덱스)` 형색의 2차원 인덱스도 제공함
#
# - `loc` 속성: 라벨 기반의 2차원 인덱서
# - `iloc` 속성: 순서를 나타내는 정수 기반의 2차원 인덱서

# %% [markdown]
# ### `loc` 인덱서
# 행 인덱스 값과 열 인덱스 값을 이용하여 인덱싱을 해주는 인덱서
#
# ```python
# df.loc[행인덱스값]
# df.loc[행인덱스값, 열인덱스값]
# ```

# %%
df = pd.DataFrame(np.arange(10,22).reshape(3,4), index=['a','b','c'], columns=['A', 'B', 'C', 'D'])
df
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21

# %%
df.loc['a']
# Out:
# A    10
# B    11
# C    12
# D    13
# Name: a, dtype: int32

# %%
df.loc[['a','b']]
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17

# %%
df.loc['a':'b']
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17

# %%
df.loc[['a']]
# Out:
#     A   B   C   D
# a  10  11  12  13

# %%
df.loc[df.A > 13]
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %% [markdown]
# 인덱스 값으로 열 인덱스 값을 반환하는 함수를 사용할 수 있음

# %%
def select_rows(df):
    return df.A > 12

# %%
df.loc[select_rows(df)]
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %% [markdown]
# `loc` 없이 인덱싱을 할 때는 `[]`에 열 인덱스에 대한 인덱싱을 하였는데 `loc`는 열 인덱싱으로 지정할 수 없음

# %%
df.loc['A']     #에러

# %% [markdown]
# `loc` 인덱싱에서 정수로 되어있는 행이라고 할 지라도 슬라이싱시에 종료 인덱스값에 대한 결과도 포함하여 출력됨

# %%
df2 = pd.DataFrame(np.arange(10,26).reshape(4,4), columns= ['A','B','C','D'])
df2
# Out:
#     A   B   C   D
# 0  10  11  12  13
# 1  14  15  16  17
# 2  18  19  20  21
# 3  22  23  24  25

# %%
df2.loc[0:2]
# Out:
#     A   B   C   D
# 0  10  11  12  13
# 1  14  15  16  17
# 2  18  19  20  21

# %% [markdown]
# #### 인덱싱 값으로 행과 열 모두 지정
# `loc[행인덱스, 열인덱스]` 로 행과 열에 대한 인덱싱을 할 수 있음

# %%
df.loc['a','A']
# Out:
# 10

# %%
df.loc['b':,:'C']
# Out:
#     A   B   C
# b  14  15  16
# c  18  19  20

# %%
df.loc[df.A > 13, ['B','C']]
# Out:
#     B   C
# b  15  16
# c  19  20

# %% [markdown]
# ### `iloc` 인덱서
# `iloc` 인덱서는 `loc` 인덱서와 사용방법은 동일하나 인덱스로 지정하는 값이 순서를 나타내는 정수 값임

# %%
df
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21

# %%
df.iloc[0,1]
# Out:
# 11

# %%
df.iloc[:2,1:]
# Out:
#     B   C   D
# a  11  12  13
# b  15  16  17

# %%
df.iloc[2]
# Out:
# A    18
# B    19
# C    20
# D    21
# Name: c, dtype: int32

# %% [markdown]
# ##### 파이썬으로 다음 연산을 수행한다.
#
# 1. real_estate 데이터베이스의 officetel_estate 테이블을 데이터프레임으로 가져옴
# 2. 상위 10개에 대한 레코드를 가지는 데이터프레임을 생성
# 3. locale이 seoul_downtown 인 레코드를 가지는 데이터프레임을 생성
# 4. between_lease_and_lease_deposit_ratio가 10 이상인 레코드의 locale, base_month 컬럼만 가지는 데이터프레임을 생성

# %%
import mysql.connector

# %%
practice_df = None

try:
    conn = mysql.connector.connect(
        host= '127.0.0.1',
        user= 'root',
        password= 'root',
        database= 'real_estate'
    )
    if conn.is_connected():
        query = 'SELECT * FROM officetel_estate'
        practice_df = pd.read_sql_query(query, conn, index_col='sequence')
        
except Exception as e:
    pass
finally:
    if conn.is_connected():
        conn.close()

practice_df
# Out:
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8896\2972445764.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   practice_df = pd.read_sql_query(query, conn, index_col='sequence')
#                   locale base_month  between_lease_and_lease_deposit_ratio  \
# sequence
# 1             nationwide     Jul-20                                   7.95
# 2           metropolitan     Jul-20                                   7.46
# 3               province     Jul-20                                   9.96
# 4                  seoul     Jul-20                                   7.10
# 5         seoul-downtown     Jul-20                                   6.13
# ...                  ...        ...                                    ...
# 727              gwangju     Jan-24                                   7.86
# 728              daejeon     Jan-24                                  11.42
# 729                ulsan     Jan-24                                   7.62
# 730               sejong     Jan-24                                   6.05
# 731             gyeonggi     Jan-24                                   7.09
#
#           lease_to_sale_ratio  monthly_rent_rate_of_return  \
# sequence
# 1                       83.54                         4.75
# 2                       84.31                         4.61
# 3                       80.33                         5.35
# 4                       82.80                         4.33
# 5                       79.55                         4.18
# ...                       ...                          ...
# 727                     83.49                         6.10
# 728                     86.32                         7.54
# 729                     83.34                         5.32
# 730                     86.15                         6.30
# 731                     85.40                         5.35
#
#           average_lease_on_deposit_price  \
# sequence
# 1                                 163525
# 2                                 175996
# 3                                 111980
# 4                                 199524
# 5                                 235665
# ...                                  ...
# 727                               105940
# 728                               101796
# 729                               117651
# 730                                97749
# 731                               183448
#
#           average_lease_on_deposit_price_per_unit  \
# sequence
# 1                                            4370
# 2                                            4797
# 3                                            2603
# 4                                            6033
# 5                                            6405
# ...                                           ...
# 727                                          2595
# 728                                          2355
# 729                                          2921
# 730                                          3522
# 731                                          4649
#
#           midian_lease_on_deposit_price  \
# sequence
# 1                                156386
# 2                                167524
# 3                                110353
# 4                                190788
# 5                                223768
# ...                                 ...
# 727                              110677
# 728                              101257
# 729                              116039
# 730                               93146
# 731                              169240
#
#           midian_lease_on_deposit_price_per_unit  average_monthly_rent_price  \
# sequence
# 1                                           4266                       13107
# 2                                           4682                       13656
# 3                                           2545                       10837
# 4                                           6025                       15250
# 5                                           6221                       13906
# ...                                          ...                         ...
# 727                                         2551                        9126
# 728                                         2201                       12090
# 729                                         2899                        9253
# 730                                         3403                        6064
# 731                                         4485                       15009
#
#           average_monthly_rent_price_unit  midian_average_monthly_rent_price  \
# sequence
# 1                                     661                              10705
# 2                                     698                              11247
# 3                                     507                               8466
# 4                                     777                              12876
# 5                                     946                              13701
# ...                                   ...                                ...
# 727                                   545                               8927
# 728                                   556                               9341
# 729                                   563                               9621
# 730                                   552                               5898
# 731                                   806                              10620
#
#           midian_average_monthly_rent_price_unit  average_sale_price  \
# sequence
# 1                                            634              203454
# 2                                            668              217040
# 3                                            492              147304
# 4                                            744              251315
# 5                                            919              310153
# ...                                          ...                 ...
# 727                                          540              132817
# 728                                          550              123572
# 729                                          555              144356
# 730                                          547              118063
# 731                                          767              231384
#
#           average_price_per_unit  midian_average_sale_price  \
# sequence
# 1                           5272                     190155
# 2                           5751                     202398
# 3                           3295                     139555
# 4                           7342                     235222
# 5                           8155                     307248
# ...                          ...                        ...
# 727                         3124                     130755
# 728                         2742                     118458
# 729                         3493                     140185
# 730                         4101                     111110
# 731                         5558                     214777
#
#           midian_average_price_per_unit
# sequence
# 1                                  4997
# 2                                  5434
# 3                                  3191
# 4                                  7064
# 5                                  7901
# ...                                 ...
# 727                                2901
# 728                                2513
# 729                                3457
# 730                                3869
# 731                                5332
#
# [731 rows x 17 columns]

# %%
# 상위 10개에 대한 레코드를 가지는 데이터프레임을 생성
practice_df.loc[:9]
# practice_df.iloc[:10]

# %%
# locale이 seoul_downtown 인 레코드를 가지는 데이터프레임을 생성
practice_df.loc[practice_df.locale == 'seoul-downtown']

# %%
# between_lease_and_lease_deposit_ratio가 10 이상인 레코드의 locale, base_month 컬럼만 가지는 데이터프레임을 생성
practice_df.loc[practice_df.between_lease_and_lease_deposit_ratio >= 10, ['locale','base_month']]
